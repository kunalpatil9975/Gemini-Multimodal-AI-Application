# %%
# Install or upgrade the Google Generative AI Python SDK
! pip install -q -U google-generativeai

# %%
# Set the Gemini API key and configure the Gemini SDK
import os
import google.generativeai as genai

os.environ["GEMINI_API_KEY"] = "AQ.Ab8RN6JSzvlO80YAUL51FGOlq6lQluiYdkI7Ok-bC_kaH2AaJg"

genai.configure(api_key=os.environ["GEMINI_API_KEY"])

# %%
# List Gemini models available for content generation
import google.generativeai as genai

for model_info in genai.list_models():
    if "generateContent" in model_info.supported_generation_methods:
        print(model_info.name)
# Out:
# models/gemini-2.5-flash
# models/gemini-2.5-pro
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/gemma-4-26b-a4b-it
# models/gemma-4-31b-it
# models/gemini-flash-latest
# models/gemini-flash-lite-latest
# models/gemini-pro-latest
# models/gemini-2.5-flash-lite
# models/gemini-2.5-flash-image
# models/gemini-3-flash-preview
# models/gemini-3.1-pro-preview
# models/gemini-3.1-pro-preview-customtools
# models/gemini-3.1-flash-lite-preview
# models/gemini-3.1-flash-lite
# models/gemini-3-pro-image-preview
# models/gemini-3-pro-image
# models/nano-banana-pro-preview
# models/gemini-3.1-flash-image-preview
# models/gemini-3.1-flash-image
# models/gemini-3.1-flash-lite-image
# models/gemini-3.5-flash
# models/gemini-3.5-flash-lite
# models/gemini-omni-flash-preview
# models/gemini-omni-1.1-flash
# models/gemini-3.5-transcribe
# models/gemini-3.6-flash
# models/gemini-3.7-flash
# models/gemini-3.8-flash
# models/lyria-3-clip-preview
# ...

# %%
# Initialize the Gemini 2.5 Flash model
# model = genai.GenerativeModel("models/gemini-2.5-flash-preview-05-20")
# model = genai.GenerativeModel("models/gemini-2.5-flash-lite-preview-06-17")

# Initialize the Gemini 2.5 Flash model
model = genai.GenerativeModel("models/gemini-2.5-flash")

# %%
# Generate a structured tabular comparison of major AI concepts
response = model.generate_content(
    """
    Create a clear and professional table comparing:
    AI, Machine Learning, Deep Learning, Generative AI, LLM, and Agentic AI.

    Include the following columns:
    1. Concept
    2. Definition
    3. Purpose
    4. How it works
    5. Key technologies
    6. Real-world examples
    7. Applications
    8. Key difference

    Make the explanation simple, technically accurate, and suitable for an AI/ML interview.
    """
)

print(response.text)
# Out:
# ---------------------------------------------------------------------------
# _InactiveRpcError                         Traceback (most recent call last)
# File c:\Users\kunal\anaconda\Lib\site-packages\google\api_core\grpc_helpers.py:55, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      54 try:
# ---> 55     return callable_(*args, **kwargs)
#      56 except grpc.RpcError as exc:
#
# File c:\Users\kunal\anaconda\Lib\site-packages\grpc\_interceptor.py:276, in _UnaryUnaryMultiCallable.__call__(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#     267 def __call__(
#     268     self,
#     269     request: Any,
#    (...)    274     compression: Optional[grpc.Compression] = None,
#     275 ) -> Any:
# --> 276     response, ignored_call = self._with_call(
#     277         request,
#     278         timeout=timeout,
#     279         metadata=metadata,
#     280         credentials=credentials,
# ...
